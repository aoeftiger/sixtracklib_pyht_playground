# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_context('talk', font_scale=1.2, rc={'lines.linewidth': 3})
sns.set_style('whitegrid',
              {'grid.linestyle': ':', 'grid.color': 'red', 'axes.edgecolor': '0.5',
               'axes.linewidth': 1.2, 'legend.frameon': True})

import os
import pickle

import time

# %%
from scipy.constants import e, m_p, c

from scipy.constants import physical_constants

# %%
from cpymad.madx import Madx

import sixtracklib as pyst
import pysixtrack

# %%
import sys
sys.path.append('/home/oeftiger/gsi/git/python3/PyHEADTAIL/')
from PyHEADTAIL.particles import generators
# Out:
# PyHEADTAIL v1.13.5
#
#
# Warning: GPU is in principle available but no context has been initialized. Please import pycuda.autoinit at the beginning of your script before importing PyHEADTAIL if you want to use GPU functionality.

# %%
nmass = physical_constants['atomic mass constant energy equivalent in MeV'][0] * 1e-3
nmass = 0.931494061 # MAD-X value

# %%
tune_range_qx = np.arange(18.55, 18.95 + 0.01, 0.01)
tune_range_qy = tune_range_qx

# %% [markdown]
# # prepare MAD-X error sequences

# %%
# e_seed = 1

# for qx in tune_range_qx:
#     for qy in tune_range_qy:
#         qqx, qqy = int(np.round((qx%1) * 100)), int(np.round((qy%1) * 100))
        
#         filename_error_table = "./error_tables/errors_{qqx}_{qqy}_{eseed:d}".format(
#             qqx=qqx, qqy=qqy, eseed=e_seed)
        
#         if os.path.exists(filename_error_table):
#             continue

#         print ('\n\n\n=== Preparing for Qx = {:.2f} and Qy = {:.2f} ===\n\n\n'.format(qx, qy))

# %% [markdown]
# # PySTL: read in lattice with errors in full definition

# %%
nturns = 20000 #2**16
npart = 1000

A = 238
Q = 28

Ekin_per_nucleon = 0.2e9 # in eV

###

mass = A * nmass * 1e9 * e / c**2 # in kg
charge = Q * e # in Coul

Ekin = Ekin_per_nucleon * A
p0c = np.sqrt(Ekin**2 + 2*Ekin*mass/e * c**2) # in eV

Etot = np.sqrt(p0c**2 + (mass/e)**2 * c**4) * 1e-9 # in GeV
p0 = p0c / c * e # in SI units
gamma = np.sqrt(1 + (p0 / (mass * c))**2)
beta = np.sqrt(1 - gamma**-2)

# %%
epsx_rms_fin = 35e-6 / 4 # geometrical emittances
epsy_rms_fin = 15e-6 / 4

limit_n_rms_x = 2
limit_n_rms_y = 2
limit_n_rms_z = 3.4

sig_z = 58 / 4. # in m
sig_dp = 0.5e-3

###

epsx_gauss = epsx_rms_fin * 1.778
epsy_gauss = epsy_rms_fin * 1.82

epsn_x = epsx_gauss * beta * gamma
epsn_y = epsy_gauss * beta * gamma

beta_z = sig_z / sig_dp

# %%
e_seed = 1

qx = tune_range_qx[0]
qy = tune_range_qy[0]

qqx, qqy = int(np.round((qx%1) * 100)), int(np.round((qy%1) * 100))

filename_error_table = "./error_tables/errors_{qqx}_{qqy}_{eseed:d}".format(
            qqx=qqx, qqy=qqy, eseed=e_seed)

madx = Madx()
madx.options.echo = False
madx.options.warn = False

madx.call('./SIS100_RF_220618_9slices.thin.seq')

madx.command.beam(particle='ion', mass=A*nmass, charge=Q, energy=Etot)

madx.call('OpticsYEH_BeamParameters.str')
madx.call('Coll+Errors+BeamDistr.madx')

madx.input('''
select, flag=seqedit, class=collimator;
select, flag=seqedit, class=kicker;
select, flag=seqedit, class=tkicker;
select, flag=seqedit, class=elseparator;

seqedit, sequence=SIS100RING;
    remove, element=selected;
    flatten;
endedit;

select, flag=seqedit, class=marker;
seqedit, sequence=SIS100RING;
    remove, element=selected;
    install, element=SIS100RING$START, s=0;
    flatten;
endedit;
''')

madx.use(sequence='sis100ring')

### --> first match, then add errors, then TWISS!

madx.input('''
    match, sequence=SIS100RING;
    global, sequence=SIS100RING, q1={qx}, q2={qy};
    vary, name=kqf, step=0.00001;
    vary, name=kqd, step=0.00001;
    lmdif, calls=500, tolerance=1.0e-10;
    endmatch;
'''.format(qx=qx, qy=qy)
)

madx.command.eoption(add=True, seed=1)
madx.command.exec('EA_EFCOMP_MH()')
for s in range(1, 10):
    assert madx.command.exec(f'EA_rEFCOMP_QD({s},1)')

twiss = madx.twiss();

madx.command.select(flag='error', pattern='QD11..', class_='MULTIPOLE')
madx.command.select(flag='error', pattern='QD12..', class_='MULTIPOLE')
madx.command.select(flag='error', pattern='mh1', class_='MULTIPOLE')
madx.command.select(flag='error', pattern='mh2', class_='MULTIPOLE')
madx.command.esave(file=filename_error_table)

madx.input('cavity_voltage = 58.2/1000/number_cavities;')

madx.command.readtable(file=filename_error_table, table="errors")
errors = madx.table.errors

sis100 = madx.sequence.sis100ring

# particle initialisation from pyheadtail

D_x_0 = twiss['dx'][0] * beta
D_y_0 = twiss['dy'][0] * beta

np.random.seed(0)

pyht_beam = generators.generate_Gaussian6DTwiss(
    npart, 1, charge, mass, twiss['s'][-1], gamma,
    twiss['alfx'][0], twiss['alfy'][0], twiss['betx'][0], twiss['bety'][0],
    1, epsn_x, epsn_y, 1,
    dispersion_x=D_x_0 if D_x_0 else None,
    dispersion_y=D_y_0 if D_y_0 else None,
    limit_n_rms_x=limit_n_rms_x**2, limit_n_rms_y=limit_n_rms_y**2, 
    limit_n_rms_z=limit_n_rms_z**2,
)

distribution_z_uncut = generators.gaussian2D(
    sig_z**2)
is_accepted = generators.make_is_accepted_within_n_sigma(
    epsn_rms=sig_z,
    limit_n_rms=limit_n_rms_z,
)
distribution_z_cut = generators.cut_distribution(distribution_z_uncut, is_accepted)

z, dp = distribution_z_cut(npart)
pyht_beam.z, pyht_beam.dp = z, dp / beta_z
# Out:
#   ++++++++++++++++++++++++++++++++++++++++++++
#   +     MAD-X 5.05.01  (64 bit, Linux)       +
#   + Support: mad@cern.ch, http://cern.ch/mad +
#   + Release   date: 2019.06.07               +
#   + Execution date: 2019.10.30 10:28:25      +
#   ++++++++++++++++++++++++++++++++++++++++++++
# START MATCHING
#
# number of sequences: 1
# sequence name: sis100ring
# number of variables:    2
# user given constraints: 2
# total constraints:      2
#
# START LMDIF:
#
# Initial Penalty Function =   0.16966450E+02
#
#
# call:       4   Penalty function =   0.17659335E-03
# call:       7   Penalty function =   0.43977396E-09
# call:      10   Penalty function =   0.25116050E-14
#  ++++++++++ LMDIF ended: converged successfully
# call:      10   Penalty function =   0.25116050E-14
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# Global constraint:         q1           4     1.85500000E+01     1.85500000E+01     1.26799014E-19
# Global constraint:         q2           4     1.85500000E+01     1.85500000E+01     2.51147817E-15
#
#
# Final Penalty Function =   2.51160496e-15
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# kqf                       2.77739e-01  2.81571e-01 -1.00000e+20  1.00000e+20
# kqd                      -2.77252e-01 -2.80616e-01 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   2.51160496e-15
# enter Twiss module
#
# iteration:   1 error:   1.732544E-03 deltap:   0.000000E+00
# orbit:  -6.780405E-04 -2.544283E-05  4.853823E-04  5.009164E-05  0.000000E+00  0.000000E+00
#
# iteration:   2 error:   2.626826E-08 deltap:   0.000000E+00
# orbit:  -6.780242E-04 -2.544629E-05  4.853717E-04  5.010438E-05  0.000000E+00  0.000000E+00
#
# ++++++ table: summ
#
#             length             orbit5               alfa            gammatr
#             1083.6                 -0     0.004221536328        15.39092545
#
#                 q1                dq1            betxmax              dxmax
#        18.54762003       -37.51433188        20.99840582        3.691459436
#
#              dxrms             xcomax             xcorms                 q2
#        1.497512109     0.001723422001    0.0007092301828         18.5523948
#
#                dq2            betymax              dymax              dyrms
#       -41.44064417        25.72786108      0.07836883437      0.03189696142
#
#             ycomax             ycorms             deltap            synch_1
#     0.001264929651    0.0004327030377                  0                  0
#
#            synch_2            synch_3            synch_4            synch_5
#                  0                  0                  0                  0
#
#             nflips
#                  0
# Want to make named table: errors

# %%
madx.command.track(onepass=True, onetable=True)

for i in range(npart):
    madx.command.start(
        x=pyht_beam.x[i],
        px=pyht_beam.xp[i],
        y=pyht_beam.y[i],
        py=pyht_beam.yp[i],
        t=pyht_beam.z[i] / beta,
        pt=pyht_beam.dp[i] * beta
    )
# Out:
# enter TRACK module
# one pass is on
# True

# %% [markdown]
# 30.10. um 11:00 Uhr gestartet:

# %%
madx.command.run(turns=nturns, ffile=nturns)
# Out:
# particle #   195 lost turn    966  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -1.3591089524734935E-002   Y=  -1.2931374798855193E-002   T=   1909.0932687290488
# particle #   561 lost turn    985  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -1.0517103969553800E-002   Y=   4.6244382985203810E-003   T=   1909.1741472290246
# particle #   896 lost turn    993  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   2.4367902511885309E-002   Y=   3.9672215082162997E-003   T=  -1909.3223145683603
# particle #   237 lost turn   1009  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -1.9197574480942425E-003   Y=  -7.7140928728695272E-003   T=  -1909.3669177823101
# particle #   812 lost turn   1086  at pos. s =    208.64 element=s23be11                                          aperture =RF-Bucket
#     X=   4.7955357965192066E-003   Y=  -1.7403337768357573E-003   T=  -1908.8025788426344
# particle #   489 lost turn   1158  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.7592537558179064E-002   Y=  -7.4711723997574224E-003   T=   1909.0234109445323
# particle #   979 lost turn   1164  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -9.6831775436153986E-003   Y=  -3.5921202234022180E-003   T=   1909.2372932115570
# particle #   956 lost turn   1186  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -4.3383803688368172E-003   Y=   9.1012966898761372E-003   T=  -1908.9219272621319
# particle #   420 lost turn   1186  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -4.5314203202546626E-003   Y=   1.2289563575807526E-003   T=  -1908.8062780836431
# particle #   952 lost turn   1203  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   2.6042553971373014E-004   Y=   1.2828321048618488E-002   T=   1909.2336976854881
# particle #    70 lost turn   1220  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   7.8462335590731721E-004   Y=  -1.0079381092591860E-002   T=   1909.0407060036266
# particle #   513 lost turn   1236  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   2.2827180779582172E-002   Y=  -3.9357393364281481E-003   T=  -1909.2731180443423
# particle #   824 lost turn   1240  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   1.2775008310883950E-002   Y=   1.6867153940711569E-003   T=   1909.0926082253245
# particle #   482 lost turn   1266  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.5649204849142125E-002   Y=  -9.4842568927683245E-003   T=   1908.9512596712120
# particle #   153 lost turn   1267  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -7.7981953456498002E-004   Y=   1.0578147671222308E-002   T=   1909.1005761482538
# particle #   614 lost turn   1288  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.5399499760077271E-002   Y=  -3.1249637934546450E-003   T=  -1909.0133098297658
# particle #   716 lost turn   1292  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   8.5916794808692139E-003   Y=  -2.3676333108063946E-003   T=   1909.1055984670336
# particle #   293 lost turn   1294  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   5.6599733074645230E-003   Y=   3.7851444468916095E-003   T=  -1909.0930206952230
# particle #   204 lost turn   1302  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.8629419166780587E-003   Y=  -8.8618999781393051E-003   T=   1908.8900526779507
# particle #   770 lost turn   1305  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -1.4456699331972706E-002   Y=  -1.2985837035459051E-002   T=  -1909.0736273821592
# particle #   247 lost turn   1319  at pos. s =    208.64 element=s23be11                                          aperture =RF-Bucket
#     X=  -1.0136687178568800E-002   Y=  -1.2579837341042416E-002   T=  -1908.7950574426839
# particle #   338 lost turn   1323  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   1.1535115636505576E-002   Y=  -6.5212281452044999E-004   T=  -1909.0323042729972
# particle #   521 lost turn   1358  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   1.4172002998292369E-003   Y=   1.4057053284225480E-002   T=  -1909.2048983008979
# particle #   898 lost turn   1363  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -3.3405881608265810E-003   Y=   9.3775810300419510E-003   T=  -1908.8607022266385
# particle #   744 lost turn   1367  at pos. s =    556.45 element=s42be11                                          aperture =RF-Bucket
#     X=  -1.1729670434030512E-002   Y=   8.4983802229137394E-003   T=   1908.7984782282983
# particle #   244 lost turn   1380  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   1.8149871520706312E-003   Y=  -8.2104677312847679E-003   T=   1909.1902970789349
# particle #   589 lost turn   1408  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.0509151192687532E-004   Y=  -1.7541476897861012E-003   T=  -1909.0658806383449
# particle #    76 lost turn   1419  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -8.6314846261130555E-003   Y=   1.1795207726661861E-003   T=  -1909.2105137114288
# particle #    74 lost turn   1425  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   1.7250761114762998E-002   Y=   7.2621622242510396E-003   T=  -1908.9822246078747
# particle #   419 lost turn   1432  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   7.9288427145763202E-003   Y=   5.0453480008950009E-003   T=  -1908.9416583701259
# particle #   827 lost turn   1439  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -9.5115239941818714E-004   Y=   5.3160534195631128E-003   T=  -1909.2319946386767
# particle #   158 lost turn   1442  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   5.1507889155329081E-003   Y=  -2.6783652093195580E-004   T=   1908.9437285817216
# particle #   481 lost turn   1443  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -3.8721935772650440E-004   Y=   7.1698574857759420E-003   T=  -1909.1707000861427
# particle #   530 lost turn   1448  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.4436879354151968E-002   Y=   2.3156841520339494E-003   T=  -1908.9524375695821
# particle #    43 lost turn   1448  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.8812243146439273E-002   Y=  -4.9354900343604336E-004   T=   1908.7960909444232
# particle #   177 lost turn   1454  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   1.2034950836368461E-002   Y=  -2.9605039188020581E-003   T=   1909.1819536989219
# particle #    16 lost turn   1455  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -7.3915880122629434E-003   Y=   1.5552733497778120E-002   T=  -1908.9905914750211
# particle #   907 lost turn   1456  at pos. s =    547.10 element=s41be12                                          aperture =RF-Bucket
#     X=   3.7896197818068997E-003   Y=   8.2753978177782187E-003   T=  -1908.7903684427968
# particle #   939 lost turn   1480  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   4.2388982321248329E-003   Y=  -1.0556286366857470E-003   T=   1909.1467252169111
# particle #   632 lost turn   1517  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -2.5178446518157546E-003   Y=   7.6916470538757956E-003   T=  -1908.8490747788858
# particle #   595 lost turn   1527  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -7.9855631438501724E-003   Y=   1.3828217056073393E-002   T=   1908.9634454168170
# particle #   382 lost turn   1539  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   9.2327647642759803E-003   Y=  -6.7597816756321530E-004   T=  -1908.8854047102659
# particle #   417 lost turn   1540  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   9.3801333933091324E-003   Y=  -1.2811182872658623E-002   T=   1908.8504728495225
# particle #   655 lost turn   1541  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   6.4712527598840674E-004   Y=   6.4898806190006189E-003   T=  -1908.9962933031072
# particle #   111 lost turn   1544  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   2.2862942101029279E-002   Y=   4.1759894392675405E-003   T=  -1908.9606865261487
# particle #   836 lost turn   1554  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -2.0822029590368551E-005   Y=  -3.2940970222898815E-003   T=   1908.8891616674346
# particle #   207 lost turn   1559  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.0063560607775104E-002   Y=  -7.3036125066614768E-004   T=  -1909.1682750861328
# particle #   574 lost turn   1567  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   7.9226193850283379E-003   Y=   1.4335445107285238E-002   T=  -1908.8945702647866
# particle #   134 lost turn   1577  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -3.6281143320279910E-003   Y=  -6.8425318881247714E-003   T=  -1909.0244540078595
# particle #   431 lost turn   1584  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.6397404249403853E-002   Y=   1.8026865851141795E-004   T=   1909.0885869340891
# particle #   845 lost turn   1585  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -6.1325035686163008E-003   Y=   7.1696352635374433E-003   T=   1909.0600177543486
# particle #   915 lost turn   1592  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -2.2414740969576158E-002   Y=  -3.1610222458338519E-003   T=   1909.1236610843648
# particle #   443 lost turn   1594  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   1.3799852127451197E-002   Y=  -1.6153796824174918E-003   T=  -1908.8399769638231
# particle #   855 lost turn   1598  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -1.4877578613714398E-002   Y=   3.8797176062752474E-003   T=  -1908.8092580526566
# particle #   993 lost turn   1599  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.5612425873342229E-002   Y=   1.1890786896785557E-003   T=   1908.9865044131718
# particle #   878 lost turn   1614  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   9.2839953288071410E-003   Y=  -2.2324998979117404E-003   T=  -1909.1504708808966
# particle #    41 lost turn   1617  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   2.5030034479732219E-002   Y=   1.8550739639518164E-003   T=  -1908.9152613319832
# particle #   905 lost turn   1626  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.2875152802800226E-002   Y=   6.1679922204311731E-003   T=  -1909.0527486654305
# particle #    32 lost turn   1627  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -5.4216526450710607E-003   Y=   2.3145397477769233E-004   T=  -1908.9732483182702
# particle #   863 lost turn   1639  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -8.0912070624130899E-003   Y=  -4.8225394001126841E-003   T=  -1909.1168490500058
# particle #    22 lost turn   1649  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.5676339859343032E-002   Y=   6.3655582175438114E-004   T=  -1908.8339116842053
# particle #   624 lost turn   1652  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.6288306266479230E-002   Y=   8.6132653452212337E-003   T=   1909.0223093133577
# particle #   356 lost turn   1658  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -9.5601670086423625E-003   Y=  -4.4016622093703689E-003   T=   1908.9027846377644
# particle #   361 lost turn   1680  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   3.8031837550273019E-003   Y=   3.8356752430448700E-004   T=  -1908.8136145144515
# particle #   912 lost turn   1706  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.5655676491618125E-002   Y=   1.5628441377806834E-003   T=  -1908.8231753480311
# particle #    81 lost turn   1708  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.1629585577877227E-002   Y=  -5.8574261557155297E-003   T=  -1909.0368063321037
# particle #   203 lost turn   1708  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   7.8250258777854392E-003   Y=   1.6367887646642199E-002   T=  -1909.0443707522961
# particle #   607 lost turn   1712  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.8119558978641773E-002   Y=   5.0468190643425653E-003   T=   1908.9929094869558
# particle #   840 lost turn   1718  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   1.6314224702276461E-002   Y=   8.5866379097428560E-004   T=  -1908.9282420550212
# particle #   206 lost turn   1720  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   1.4612669033551493E-002   Y=   1.1020262358632939E-002   T=  -1909.1394152017062
# particle #   839 lost turn   1721  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -5.1668989427986888E-004   Y=  -1.3488957268404180E-002   T=   1909.0837449672008
# particle #   157 lost turn   1723  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   1.1796138992533932E-003   Y=  -1.9701608750976921E-003   T=   1908.9074731896555
# particle #   649 lost turn   1724  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -8.8040669843351179E-003   Y=  -1.5767354628624117E-003   T=   1908.9532845721615
# particle #   550 lost turn   1734  at pos. s =    195.25 element=s22be11                                          aperture =RF-Bucket
#     X=   8.6796325933979866E-003   Y=  -1.3047675658749187E-002   T=  -1908.7908602919979
# particle #   364 lost turn   1739  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   8.1087312826569145E-003   Y=  -4.0937588121105414E-003   T=   1909.0926904124542
# particle #   363 lost turn   1741  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   4.3546618243762557E-003   Y=  -3.7630478935389735E-003   T=   1908.8001919117494
# particle #   710 lost turn   1741  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   1.3582417578996628E-002   Y=   7.4749253216042817E-003   T=   1909.0896413200880
# particle #   326 lost turn   1751  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.2686221320365090E-003   Y=  -3.8418263446923610E-003   T=  -1909.1483473145965
# particle #   737 lost turn   1756  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -5.6925589414165778E-003   Y=   3.8369122016630275E-003   T=   1909.0096370632616
# particle #   154 lost turn   1765  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -8.4609119251070376E-003   Y=  -9.7227946014843795E-005   T=   1909.1067694132939
# particle #   869 lost turn   1768  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.9520117103771790E-003   Y=  -2.2204958510920001E-005   T=  -1909.0895276464869
# particle #   961 lost turn   1773  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -1.4712580968505380E-003   Y=  -2.8187089478540301E-003   T=  -1908.7931361759145
# particle #    11 lost turn   1780  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   3.5277056446323023E-003   Y=   2.7360736493578296E-003   T=  -1909.0151712278935
# particle #   653 lost turn   1782  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.8973128967608430E-002   Y=  -4.8604876080948559E-003   T=   1909.1003627624552
# particle #    49 lost turn   1790  at pos. s =    208.64 element=s23be11                                          aperture =RF-Bucket
#     X=   1.1619196598792798E-002   Y=   7.9735816086439846E-003   T=   1908.7965154712747
# particle #   165 lost turn   1792  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -2.0118925605110829E-002   Y=   1.1425861980932494E-003   T=   1909.1299898680770
# particle #   602 lost turn   1800  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   3.7915489929172641E-003   Y=  -5.3081479441593731E-003   T=   1908.9243553506999
# particle #    18 lost turn   1802  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -2.1852157361737217E-002   Y=  -8.2604574224067698E-003   T=  -1909.0268235946492
# particle #   927 lost turn   1812  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.4729908428146939E-003   Y=  -7.1622202921992270E-003   T=   1908.9237008099733
# particle #   536 lost turn   1821  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.1603669736067076E-002   Y=   7.0874768216496603E-003   T=   1908.8336751891054
# particle #   286 lost turn   1828  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   2.9280111541813282E-004   Y=  -5.7559406026761340E-003   T=   1908.9330938775938
# particle #   704 lost turn   1830  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -1.6123976604233339E-002   Y=   3.1681520723109298E-003   T=   1908.8106061413391
# particle #   321 lost turn   1836  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.0067571825330586E-003   Y=   3.2451795834113448E-003   T=  -1908.8693129570715
# particle #   102 lost turn   1842  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.0992632982359375E-002   Y=   1.3132212913177250E-002   T=  -1908.8188356234200
# particle #   590 lost turn   1845  at pos. s =    934.20 element=s63be12                                          aperture =RF-Bucket
#     X=  -8.2632190726177925E-003   Y=   4.9222521551337429E-003   T=   1908.7894355373139
# particle #   205 lost turn   1852  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.5179133285380300E-003   Y=   1.1292460227506332E-002   T=   1908.9027965740047
# particle #    48 lost turn   1856  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -6.6884652744434855E-003   Y=   8.4443881585864061E-005   T=   1909.0772359139878
# particle #   242 lost turn   1857  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -2.7375649043064917E-003   Y=  -4.9150520490728201E-003   T=  -1908.8675563489701
# particle #   604 lost turn   1860  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -6.8971311833181314E-003   Y=  -7.7097601867255894E-003   T=  -1908.9576487710187
# particle #   332 lost turn   1869  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   2.3557854948872705E-003   Y=   1.5192412364777533E-002   T=  -1908.8108225471926
# particle #   179 lost turn   1878  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -6.1340927732456332E-003   Y=  -3.6599408221951475E-003   T=  -1909.0336176792459
# particle #   937 lost turn   1905  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.5764830555698200E-002   Y=  -3.1038681685964346E-004   T=  -1908.8738011212104
# particle #   402 lost turn   1926  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.8842415644475901E-002   Y=   1.8220710633703504E-003   T=  -1908.9630504809727
# particle #   418 lost turn   1928  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.0318372574935095E-002   Y=   5.9480187642101936E-004   T=   1909.0905373120054
# particle #   735 lost turn   1928  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.6824403804541910E-002   Y=  -1.9408011761336726E-003   T=  -1908.8711600965762
# particle #   425 lost turn   1936  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -3.2256633595095117E-003   Y=   2.6195561657442546E-003   T=  -1909.0031269807655
# particle #   625 lost turn   1939  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -1.2518678157539215E-003   Y=  -4.8372881409629370E-003   T=   1909.0890137740882
# particle #   169 lost turn   1940  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   1.5425737884511367E-002   Y=   1.3575078894560787E-002   T=  -1908.8233365594483
# particle #   473 lost turn   1945  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   6.5823467434467505E-003   Y=   2.7106689286634329E-004   T=  -1909.0701223658916
# particle #   651 lost turn   1970  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   1.2932049272343669E-002   Y=  -6.7792761977560805E-004   T=   1908.8999449000250
# particle #   351 lost turn   1974  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   5.3545713009900860E-003   Y=   5.0452626942929738E-005   T=  -1908.8677717591424
# particle #    75 lost turn   1976  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -2.3344795376040711E-003   Y=  -4.0059103684877374E-003   T=  -1908.9096770314047
# particle #   243 lost turn   1976  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   7.9059168195058632E-003   Y=  -8.7467737512197646E-003   T=   1908.9725939769803
# particle #   842 lost turn   1981  at pos. s =    569.84 element=s43be11                                          aperture =RF-Bucket
#     X=   3.2368970820671958E-003   Y=   4.3956287385756953E-004   T=  -1908.7962515231338
# particle #   654 lost turn   1981  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   2.7589566228109824E-003   Y=   4.9911729696185377E-003   T=  -1908.9918946545577
# particle #   212 lost turn   1998  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -1.0359148200796590E-002   Y=  -8.7232710352795721E-003   T=   1908.8318388338314
# particle #   360 lost turn   2003  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   3.9931985485723402E-003   Y=   2.0714084003386197E-003   T=  -1908.9408278940814
# particle #   543 lost turn   2024  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   5.2453392338886176E-003   Y=   5.2276384747118156E-003   T=  -1908.9941241776992
# particle #   236 lost turn   2025  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   8.5912294970005212E-003   Y=   4.5435965984253392E-003   T=  -1909.0221458921928
# particle #   222 lost turn   2026  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -4.3739035178266680E-003   Y=   3.2310664463555145E-003   T=   1908.9952587480768
# particle #   133 lost turn   2031  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -1.1221155706536208E-002   Y=  -1.0296138208819611E-002   T=   1909.0401957319773
# particle #   259 lost turn   2035  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -3.2329146152238371E-003   Y=  -1.3874448271865483E-002   T=  -1909.0978245486190
# particle #   733 lost turn   2038  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.8225598362054413E-002   Y=   3.5166682052706648E-003   T=  -1908.9767575827332
# particle #   826 lost turn   2045  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.5646857668362428E-002   Y=  -6.4309334976121475E-004   T=   1909.0251228904388
# particle #   597 lost turn   2049  at pos. s =    556.45 element=s42be11                                          aperture =RF-Bucket
#     X=   7.9626404560011067E-003   Y=  -5.5584420734854844E-003   T=  -1908.7907967063263
# particle #   344 lost turn   2052  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   7.9536887373281972E-003   Y=   1.0114518394999047E-002   T=  -1908.9664219060394
# particle #   831 lost turn   2065  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   2.1660530027088256E-003   Y=   1.2362619174715265E-003   T=  -1909.0431705878434
# particle #   641 lost turn   2067  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   5.0762681171304513E-003   Y=  -8.7900283308363966E-003   T=   1909.0412309212059
# particle #   524 lost turn   2076  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   3.8897427767857016E-003   Y=   3.8071069528873630E-003   T=  -1909.0600924540856
# particle #   797 lost turn   2092  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -3.1539694530789714E-003   Y=  -6.5665791893068318E-003   T=   1908.8312629243167
# particle #   442 lost turn   2094  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.0943842484090395E-002   Y=  -7.1209644389509646E-003   T=   1908.8808543136329
# particle #   446 lost turn   2095  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -7.5760982970474221E-004   Y=  -2.2231361582837937E-003   T=  -1908.9608056546140
# particle #   455 lost turn   2099  at pos. s =    569.84 element=s43be11                                          aperture =RF-Bucket
#     X=  -2.6095159909866918E-003   Y=  -4.5835206953023780E-003   T=  -1908.7903656785429
# particle #   196 lost turn   2112  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -8.3305510610806235E-003   Y=   3.9374800262861453E-003   T=  -1909.0056295842487
# particle #    42 lost turn   2113  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -2.0522231782486147E-002   Y=  -2.3536082913726102E-003   T=   1909.0754704671208
# particle #   995 lost turn   2117  at pos. s =    185.90 element=s21be12                                          aperture =RF-Bucket
#     X=  -4.2402947336724348E-003   Y=   1.3799704076227999E-002   T=   1908.7914581623234
# particle #   109 lost turn   2117  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.2565515951361673E-002   Y=  -1.7882682429837191E-003   T=   1908.9114639638433
# particle #   620 lost turn   2121  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -3.5408036482386072E-003   Y=   4.8905369639395757E-003   T=   1908.8847981934412
# particle #   463 lost turn   2122  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.1694706953411257E-002   Y=  -7.5930180064204674E-003   T=   1908.9848100392740
# particle #   714 lost turn   2124  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   2.4797269254932894E-003   Y=  -3.3919264591463086E-003   T=  -1908.9614948920303
# particle #   947 lost turn   2126  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   3.5622197017498598E-003   Y=   5.3786032499994994E-005   T=   1908.8170123201178
# particle #   171 lost turn   2130  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.5019808773199299E-002   Y=  -4.6221372644457944E-003   T=  -1909.0618930867083
# particle #   143 lost turn   2145  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.8892441360879746E-002   Y=  -5.0399413537077368E-003   T=   1908.9005724670978
# particle #   217 lost turn   2162  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -3.7457227382428964E-003   Y=   4.1895918827252188E-003   T=  -1908.8945937659037
# particle #   613 lost turn   2163  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -2.4493236614467395E-002   Y=  -4.6880453520619714E-004   T=  -1909.0298687499303
# particle #   460 lost turn   2168  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.3705606777977778E-003   Y=  -1.2795553684170865E-002   T=  -1909.0179621789043
# particle #   456 lost turn   2173  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   3.6909986021616864E-003   Y=  -8.2216561612172053E-003   T=  -1908.8085750863731
# particle #   445 lost turn   2174  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -2.4236000000956003E-003   Y=  -5.6852762475910913E-003   T=  -1909.0060461299806
# particle #   771 lost turn   2180  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -9.5813228460120089E-004   Y=   2.3229882921135480E-003   T=  -1908.9170433378940
# particle #   287 lost turn   2180  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.1544047201853220E-002   Y=   9.7774134017755872E-003   T=   1909.0411266247056
# particle #     5 lost turn   2182  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -2.4830195580612356E-002   Y=   9.4575877909968166E-003   T=  -1909.0756317250894
# particle #   110 lost turn   2186  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -9.8413742890491596E-003   Y=   6.3285475322014187E-003   T=  -1908.9024783698449
# particle #    15 lost turn   2191  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -8.4250614154121849E-003   Y=   2.4498374177866740E-004   T=   1908.9390091166420
# particle #   788 lost turn   2192  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.0541268489877496E-002   Y=  -1.1017807372217334E-002   T=  -1908.9945239326271
# particle #   270 lost turn   2205  at pos. s =    185.90 element=s21be12                                          aperture =RF-Bucket
#     X=  -1.5012867166464321E-002   Y=  -4.8484436498787186E-003   T=  -1908.7914294020129
# particle #   786 lost turn   2210  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -5.8929574579879886E-003   Y=  -1.5281239283318937E-004   T=   1909.0799084745950
# particle #   504 lost turn   2213  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -6.3056085212083368E-003   Y=   7.5650786511486335E-003   T=  -1908.9662857589376
# particle #   696 lost turn   2213  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.5714924963743472E-002   Y=   6.1038308446455438E-003   T=   1908.9792138262069
# particle #   532 lost turn   2220  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.7574658055216166E-003   Y=   9.8202823941984682E-004   T=  -1908.8934471600483
# particle #   472 lost turn   2228  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -5.3431191743415693E-003   Y=  -5.3901069909294275E-003   T=  -1908.8738979559701
# particle #   541 lost turn   2239  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   3.8715183453778374E-003   Y=   1.0534108778141513E-002   T=   1908.7937921800351
# particle #   920 lost turn   2239  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -8.0273413177167820E-003   Y=   1.2563833922435643E-003   T=  -1909.0416461167711
# particle #   763 lost turn   2252  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -2.5187946344684228E-002   Y=  -6.5136176708262862E-003   T=  -1908.9256632681593
# particle #   793 lost turn   2257  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -1.4638745435048795E-002   Y=  -1.4187782043697571E-003   T=  -1908.9953194243053
# particle #   415 lost turn   2263  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   8.4200047828081812E-003   Y=  -4.7591014904705548E-006   T=   1908.9940584351145
# particle #   953 lost turn   2266  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   2.5220924137238608E-003   Y=   1.0881217892320006E-004   T=   1909.0678457482343
# particle #     4 lost turn   2267  at pos. s =    547.10 element=s41be12                                          aperture =RF-Bucket
#     X=   1.5212008133935716E-002   Y=   7.1410804000301524E-003   T=  -1908.7911963323513
# particle #    64 lost turn   2271  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.2388552186192114E-002   Y=  -2.7597915094435908E-003   T=  -1908.8542042899103
# particle #   910 lost turn   2272  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   7.2557459784209286E-003   Y=   1.3037482817430881E-002   T=  -1909.0111311244552
# particle #   693 lost turn   2283  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   6.9362913041616028E-003   Y=  -1.8897515032521468E-003   T=   1908.8755947098109
# particle #   600 lost turn   2284  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -4.1340735184101579E-003   Y=  -3.0349707891309721E-003   T=  -1908.9862443717263
# particle #   365 lost turn   2303  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   5.5254171697476026E-003   Y=   4.4427699132741413E-003   T=  -1908.8255990863836
# particle #   555 lost turn   2313  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.4191009726944852E-002   Y=   3.9599557690420412E-003   T=   1909.0491300147955
# particle #   885 lost turn   2313  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -4.5266557985864930E-003   Y=   6.9910423600292601E-003   T=   1909.0424089788398
# particle #   377 lost turn   2319  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   7.1679244163822455E-003   Y=  -1.3283985502978863E-002   T=  -1909.0147626531723
# particle #   664 lost turn   2320  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   1.4712560876745931E-002   Y=   1.6528190332339817E-002   T=  -1909.0271021692486
# particle #   856 lost turn   2321  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   2.1439474129506270E-003   Y=   4.4759294053014547E-003   T=  -1908.9684115919472
# particle #   916 lost turn   2321  at pos. s =    547.10 element=s41be12                                          aperture =RF-Bucket
#     X=  -5.6904961461552057E-003   Y=  -4.7627517017084205E-003   T=  -1908.7907993437393
# particle #   101 lost turn   2323  at pos. s =    185.90 element=s21be12                                          aperture =RF-Bucket
#     X=  -1.1705203736013563E-002   Y=  -7.4197326787106755E-005   T=   1908.7892570732183
# ...
#     X=   8.4979829795045203E-003   Y=  -6.6346379020811239E-003   T=  -1908.8937935699637
# particle #   738 lost turn   6967  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -4.4379309355236417E-003   Y=  -1.2193501589818558E-002   T=  -1908.8111173359548
# particle #   167 lost turn   7022  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.1044778161838430E-002   Y=  -1.6512472171580389E-002   T=  -1908.8408009501529
# particle #   499 lost turn   7041  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   2.2246008874210833E-002   Y=   8.9414550379922136E-004   T=  -1908.7948482812476
# particle #   538 lost turn   7062  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.3278999152780823E-003   Y=   3.0138516607311617E-003   T=   1908.8433061688866
# particle #   661 lost turn   7077  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   7.2351809523438435E-003   Y=   1.6541389346374671E-003   T=   1908.8627278290528
# particle #   778 lost turn   7130  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   1.6251039483432892E-003   Y=   2.8418916710641687E-003   T=   1908.7980647923303
# particle #   284 lost turn   7335  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.5297798069222705E-002   Y=  -7.7219853889646719E-003   T=  -1908.8469150442925
# particle #   582 lost turn   7362  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   1.3630977745881382E-002   Y=  -1.1161094829562901E-003   T=   1908.8484619938349
# particle #   709 lost turn   7441  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -8.6930102584737157E-003   Y=  -1.1107353650325171E-003   T=   1908.7955406427113
# particle #   564 lost turn   7467  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -3.5759613174597797E-003   Y=  -6.5900755459047736E-004   T=   1908.7985654254630
# particle #   917 lost turn   7561  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.6696528812980387E-003   Y=  -9.4082390893947543E-003   T=  -1908.8853346234230
# particle #   843 lost turn   7590  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -3.4410403300648537E-003   Y=  -2.6911339807629392E-003   T=  -1908.8426370834466
# particle #   531 lost turn   7604  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -6.5930281791835854E-004   Y=  -1.9755634476793841E-003   T=  -1908.7965071605536
# particle #   634 lost turn   7678  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -3.1232560498188917E-003   Y=  -8.6756026337250439E-003   T=  -1908.8019498881192
# particle #   140 lost turn   7716  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   2.5105441990699888E-003   Y=  -7.2273008396563834E-003   T=   1908.8112828069916
# particle #   943 lost turn   7721  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -5.6334690773833847E-003   Y=   8.9266954085577763E-003   T=   1908.8332969960422
# particle #   296 lost turn   7726  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -6.4860377611460421E-003   Y=   2.1571879422832762E-003   T=  -1908.8358891230794
# particle #   139 lost turn   7753  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.7389816711983780E-002   Y=   1.2476047505663168E-002   T=  -1908.8006794265623
# particle #    56 lost turn   7845  at pos. s =    208.64 element=s23be11                                          aperture =RF-Bucket
#     X=  -3.9930625239301670E-003   Y=   1.2453968694997611E-002   T=   1908.7917783842902
# particle #   800 lost turn   7856  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -7.2314853896029941E-003   Y=  -2.3205879692461927E-003   T=   1908.8973749192796
# particle #   478 lost turn   7933  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   3.2866399772359996E-003   Y=   1.1720052267105053E-002   T=  -1908.8507753702643
# particle #   290 lost turn   7936  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   4.6171594340900365E-003   Y=  -1.9005371262435363E-003   T=   1908.7985592721541
# particle #   251 lost turn   7957  at pos. s =    208.64 element=s23be11                                          aperture =RF-Bucket
#     X=   1.3101509827226836E-002   Y=   5.5882781230523447E-003   T=  -1908.7910865498850
# particle #   684 lost turn   7960  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   1.6424409420056261E-003   Y=   7.9073415843126556E-003   T=   1908.8412374872005
# particle #   560 lost turn   7996  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   5.4861604818247159E-003   Y=   8.1416589230470585E-003   T=  -1908.7998536160471
# particle #   303 lost turn   8088  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -5.2134331366407282E-003   Y=   4.6709339970980412E-004   T=  -1908.8090372892525
# particle #   922 lost turn   8116  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   8.8729818845562566E-003   Y=   6.9093373005000890E-003   T=  -1908.8946022049806
# particle #   935 lost turn   8189  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   3.1958711732622356E-003   Y=  -1.5626039187541865E-003   T=   1908.8175072450854
# particle #   978 lost turn   8191  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -3.5791045236778082E-003   Y=   6.3296024182804911E-003   T=   1908.8884837466583
# particle #   666 lost turn   8225  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   4.7777503001690076E-003   Y=  -8.5526648751725661E-003   T=   1908.8131425287484
# particle #   385 lost turn   8230  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -4.3900441832139770E-004   Y=  -1.3323987286520387E-003   T=   1908.8070940742070
# particle #   127 lost turn   8386  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -4.1352614775648847E-003   Y=   3.2447560000885209E-003   T=  -1908.8254268891849
# particle #   295 lost turn   8441  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -1.8944633497226287E-002   Y=  -3.4328213163556573E-003   T=   1908.8702301326273
# particle #   592 lost turn   8662  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   3.2818678401048207E-003   Y=   2.1657770134443140E-003   T=  -1908.8864200643536
# particle #   789 lost turn   8665  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -1.1827288935554237E-002   Y=  -9.6721759312369676E-003   T=   1908.8284504808221
# particle #   512 lost turn   8722  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   3.9004753967733317E-003   Y=  -2.2155192840936561E-002   T=   1908.7922877808505
# particle #   889 lost turn   8778  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -6.7358031982769906E-003   Y=  -1.9714818389243325E-003   T=   1908.8286242026584
# particle #   631 lost turn   8883  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   2.4842289874224713E-003   Y=  -2.6591076846201362E-003   T=  -1908.7924811941975
# particle #   629 lost turn   8983  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -5.7302202230229277E-003   Y=  -3.2869637404274407E-003   T=   1908.8865474773047
# particle #   347 lost turn   9021  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   2.2755728489486297E-003   Y=   8.8742329952119451E-003   T=  -1908.8635255137442
# particle #    72 lost turn   9116  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   2.5415471920965434E-003   Y=  -1.5557607189570007E-002   T=  -1908.8427080501035
# particle #   951 lost turn   9128  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -6.5036786771337698E-003   Y=  -3.6228298168282168E-003   T=   1908.8986383838621
# particle #   967 lost turn   9142  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   7.1267358361179652E-004   Y=   8.8929682569521308E-003   T=  -1908.8720809122301
# particle #   488 lost turn   9148  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   2.2306544480108176E-004   Y=   9.8622552245904264E-003   T=   1908.8625381750085
# particle #   619 lost turn   9323  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   1.5310437159908707E-002   Y=  -6.0949026980774926E-003   T=   1908.8491947105867
# particle #   963 lost turn   9733  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   8.4191709725810714E-003   Y=   2.8938259620175906E-003   T=  -1908.8108142038866
# particle #   645 lost turn   9773  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   8.1637145904858710E-003   Y=   1.1471767753727113E-002   T=  -1908.8405630612260
# particle #   695 lost turn   9893  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   6.3642601420871078E-003   Y=   2.4114649553637069E-003   T=  -1908.8025455328200
# particle #    57 lost turn  10330  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -7.8907013570075624E-003   Y=   1.4328918980294406E-002   T=   1908.8306242907565
# particle #   272 lost turn  10389  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   3.9067109446428474E-004   Y=   7.6400678043250809E-003   T=   1908.8723182632675
# particle #   761 lost turn  10497  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=  -1.1696356307133757E-003   Y=   6.6231970796192495E-005   T=   1908.8508314113049
# particle #   378 lost turn  10659  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=  -7.1807878724328544E-003   Y=   1.1368208802611335E-003   T=  -1908.8133070997678
# particle #   151 lost turn  10735  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   8.7935413564191201E-003   Y=  -3.6231241766409628E-004   T=  -1908.8178401103914
# particle #   819 lost turn  11021  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=   7.9967368141832130E-003   Y=  -1.3854067708621557E-002   T=  -1908.8795315009104
# particle #   674 lost turn  11131  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   6.9526766353541908E-003   Y=   2.1171104746775826E-003   T=  -1908.8578376983376
# particle #   149 lost turn  11374  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   5.1872351297830663E-003   Y=  -1.2585121571044746E-002   T=   1908.8027148534802
# particle #   598 lost turn  11569  at pos. s =    182.74 element=s21be11                                          aperture =RF-Bucket
#     X=   1.7909179443660685E-002   Y=   2.1314923291381161E-003   T=  -1908.8677643287183
# particle #   606 lost turn  11604  at pos. s =    543.94 element=s41be11                                          aperture =RF-Bucket
#     X=  -3.9964660207677544E-003   Y=   1.4063820515726557E-003   T=   1908.8447144913691
# particle #   384 lost turn  12459  at pos. s =    931.04 element=s63be11                                          aperture =RF-Bucket
#     X=   1.3569063243136950E-003   Y=   1.9612475421837673E-002   T=  -1908.8543512422993
# True

# %%
len(ttt.split('particle #')) - 1
# Out:
# 620

# %%
madx.command.endtrack()
# Out:
# exit TRACK module
# True

# %%
import time
time.time()
# Out:
# 1572477379.5709963

# %%
from datetime import datetime

# %%
datetime.fromtimestamp(1572477379.5709963)
# Out:
# datetime.datetime(2019, 10, 31, 0, 16, 19, 570996)

# %%
t0 = time.time()

trackjob.track_until(nturns)
trackjob.collect()

store = {}
filename_error_table = os.path.basename(filename_error_table)

# statistics
x = trackjob.output.particles[0].x.reshape((nturns, npart)).T
store['std_x'] = np.mean(np.std(x, axis=0)[-50:])
y = trackjob.output.particles[0].y.reshape((nturns, npart)).T
store['std_y'] = np.mean(np.std(y, axis=0)[-50:])

# losses
pbuffer = trackjob.particles_buffer.get_object(0)
np.save('results/' + filename_error_table + '_alive.npy', pbuffer.state)
np.save('results/' + filename_error_table + '_lost_at_element.npy', 
        pbuffer.at_element[~pbuffer.state.astype(bool)])
np.save('results/' + filename_error_table + '_lost_at_turn.npy',
        pbuffer.at_turn[~pbuffer.state.astype(bool)])

store['losses'] = np.sum(pbuffer.state)

# finish job
pickle.dump(store, open('results/' + filename_error_table + '_summary.p', 'wb'))

# !touch "results/$filename_error_table"_done

del trackjob, elements, particles

t1 = time.time()

# %%
(t1 - t0) / 60.
# Out:
# 33.21658913691839

# %%
np.sum(pbuffer.state)
# Out:
# 712

# %%
# !ls ./Vera_1match-2err_55_55/
# Out:
# 1match-2err.zip  track_55_55_1_20000_one  tracksumm_55_55_1_20000
# errors_55_55_1	 trackloss_55_55_1_2000   twiss_55_55_1
# matched_55_55_1  tracksumm_1.madx

# %%
np.genfromtxt('./Vera_1match-2err_55_55/tracksumm_55_55_1_20000', skip_header=8)[:1000]
# Out:
# array([[ 1.00000000e+00,  0.00000000e+00, -1.49495704e-02, ...,
#          2.86873274e-04,  0.00000000e+00,  0.00000000e+00],
#        [ 2.00000000e+00,  0.00000000e+00, -1.56963544e-02, ...,
#          2.83204003e-04,  0.00000000e+00,  0.00000000e+00],
#        [ 3.00000000e+00,  0.00000000e+00,  2.21776800e-02, ...,
#          3.34435334e-05,  0.00000000e+00,  0.00000000e+00],
#        ...,
#        [ 9.98000000e+02,  0.00000000e+00,  1.80188790e-02, ...,
#          2.13486304e-04,  0.00000000e+00,  0.00000000e+00],
#        [ 9.99000000e+02,  0.00000000e+00, -1.52037930e-02, ...,
#          8.33387393e-05,  0.00000000e+00,  0.00000000e+00],
#        [ 1.00000000e+03,  0.00000000e+00, -1.04522653e-02, ...,
#         -2.65525862e-04,  0.00000000e+00,  0.00000000e+00]])

# %%
# !head -7 ./Vera_1match-2err_55_55/tracksumm_55_55_1_20000 | tail -1
# Out:
# *     NUMBER       TURN                  X                 PX                  Y                 PY                  T                 PT                  S                  E

# %%
np.genfromtxt('./Vera_Tunes_Emittances.dat')
# Out:
# array([[           nan,            nan,            nan, ...,
#                    nan,            nan,            nan],
#        [5.50000000e+01, 5.50000000e+01, 1.00000000e+00, ...,
#         5.10266004e-06, 5.10787475e-06, 7.95000000e+02],
#        [5.50000000e+01, 5.60000000e+01, 1.00000000e+00, ...,
#         8.18066600e-06, 4.36666198e-06, 9.86000000e+02],
#        ...,
#        [9.50000000e+01, 9.30000000e+01, 1.00000000e+00, ...,
#         1.57863354e-05, 3.99121279e-06, 8.97000000e+02],
#        [9.50000000e+01, 9.40000000e+01, 1.00000000e+00, ...,
#         1.33605337e-05, 3.83190357e-06, 6.96000000e+02],
#        [9.50000000e+01, 9.50000000e+01, 1.00000000e+00, ...,
#         6.88273417e-06, 4.73707620e-06, 3.33000000e+02]])

# %%
# e_seed = 1

# for qx in tune_range_qx:
#     for qy in tune_range_qy:
#         qqx, qqy = int(np.round((qx%1) * 100)), int(np.round((qy%1) * 100))
        
#         filename_error_table = "./errors_{qqx}_{qqy}_{eseed:d}".format(
#             qqx=qqx, qqy=qqy, eseed=e_seed)
        
#         if os.path.exists(filename_error_table + '_done'):
#             continue
        
#         print ('\n\n\n=== Running at Qx = {:.2f} and Qy = {:.2f} ===\n\n\n'.format(qx, qy))
        
#         # read in MAD-X sequence with errors
        
#         madx = Madx()
#         madx.options.echo = False
#         madx.options.warn = False
#         madx.options.info = False
        
#         madx.call(file=filename_error_table + '_full-lattice.seq')
        
#         madx.command.beam(particle='ion', mass=238*nmass, charge=28, energy=238*0.2+238*nmass)
        
#         madx.use(sequence='SIS100RING')
        
#         twiss = madx.twiss();
        
#         sis100 = madx.sequence.sis100ring
        
#         assert 2 == len(
#             [f.name for f in map(lambda x: x.base_type, sis100.expanded_elements) 
#              if 'drift' != f.name and 'multipole' != f.name and 'rfcavity' != f.name])
        
#         # go to PySTL
        
#         elements = pyst.Elements.from_mad(sis100)

#         elements.BeamMonitor(num_stores=nturns);

#         particles = pyst.Particles.from_ref(npart, p0c=p0c, q0=28, mass0=238*nmass*1e9)
        
#         # matching

#         np.random.seed(987654321)

#         x = np.random.normal(
#             loc=0, scale=np.sqrt(twiss['betx'][0] * epsx_gauss), size=npart)
#         xp = np.random.normal(
#              loc=0, scale=np.sqrt(epsx_gauss / twiss['betx'][0]), size=npart)
#         xp += -twiss['alfx'][0] / twiss['betx'][0] * x

#         y = np.random.normal(
#             loc=0, scale=np.sqrt(twiss['bety'][0] * epsy_gauss), size=npart)
#         yp = np.random.normal(
#              loc=0, scale=np.sqrt(epsy_gauss / twiss['bety'][0]), size=npart)
#         yp += -twiss['alfy'][0] / twiss['bety'][0] * y

#         z = np.random.normal(loc=0, scale=sig_z, size=npart)
#         dp = np.random.normal(loc=0, scale=sig_dp, size=npart)

#         particles.x *= 0
#         particles.px *= 0
#         particles.y *= 0
#         particles.py *= 0
#         particles.zeta *= 0
#         particles.delta *= 0

#         particles.x += x
#         particles.px += xp
#         particles.y += y
#         particles.py += yp
#         particles.zeta += z
#         particles.delta += dp
        
#         # PySTL job
        
#         job = pyst.TrackJob(elements, particles, device=pystl_device)

#         job.track(nturns)

#         job.collect()
        
#         # coordinates
# #         np.save(filename_error_table + '_x.npy', job.output.particles[0].x)
# #         np.save(filename_error_table + '_y.npy', job.output.particles[0].y)
# #         np.save(filename_error_table + '_px.npy', job.output.particles[0].px)
# #         np.save(filename_error_table + '_py.npy', job.output.particles[0].py)
# #         np.save(filename_error_table + '_zeta.npy', job.output.particles[0].zeta)
# #         np.save(filename_error_table + '_delta.npy', job.output.particles[0].delta)

#         store = {}

#         # statistics
#         x = job.output.particles[0].x.reshape((nturns, npart)).T
#         store['std_x'] = np.mean(np.std(x, axis=0)[-50:])
#         y = job.output.particles[0].y.reshape((nturns, npart)).T
#         store['std_y'] = np.mean(np.std(y, axis=0)[-50:])
        
#         # losses
#         pbuffer = job.particles_buffer.get_object(0)
#         np.save(filename_error_table + '_alive.npy', pbuffer.state)
#         np.save(filename_error_table + '_lost_at_element.npy', 
#                 pbuffer.at_element[~pbuffer.state.astype(bool)])
#         np.save(filename_error_table + '_lost_at_turn.npy',
#                 pbuffer.at_turn[~pbuffer.state.astype(bool)])
        
#         store['losses'] = np.sum(pbuffer.state)
        
#         # finish job
#         pickle.dump(store, open(filename_error_table + '_summary.p', 'wb'))

#         !touch "$filename_error_table"_done
        
#         del job, elements, particles
